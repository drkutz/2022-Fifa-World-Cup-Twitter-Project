# %% [markdown]
# ## DS 710 Final Project 3
# ## Completed by Adam Gruber

# %% [markdown]
# ## Research Question:
#
# The Fifa world cup only occurs once every 4 years. The games are predicted to have 5 billion viewers over the course of the
# event. That is a marketing gold when comapred to other large sporting events such as the Super Bowl. Customer interest can
# change on the fly based on the performance of certain countries and which ones remain in the event. Twitter allows real
# time feed back and for measuring engagement.  Our goal is to find out the level of excitement and positve attitude towards
# each of the remaining 4 countries. Is their a fan favorite among our collection? Would online product tie-ins be more
# beneficial for one country vs another? Since England and America are no longer in the running for world cup champion I suspected France would likely be the next top contender for tweets since they are large Western European nation with many ties to the English Speaking world. 2022 Final Four for World Cup are Argentina, Morocco, France, and Croatia.

# %% [markdown]
# ### Data Collection:
#
# I collected 1000 tweets from using Twitter_API using the Tweepy Library. The key word used for searches was @Fifa.  They were collected on 12/11/2022 before the Final Four match ups. They were collected after the Final Four were determined. When England lost to France.

# %%
import warnings
warnings.filterwarnings('ignore')
from Twitter_visualizations import lang_hist, sentiment_hist, country_bar, sentiment_grid, location_list

# %% [markdown]
# ### Intial Data Exploration
#
# The twitter platform allows peope of various languages to interact. In order to ensure accuracy in sentiment analysis, tweets were sorted by language and non english tweets were removed. Vader Sentiment module does not have the ability to read any languages other than English. Fifa world cup is a an international sport.  Twitter is a English based, western company and I expected the majority of the Tweets to be in English. 881 of the tweets were in English.

# %%
lang_hist()
# Out:
# [Text(0.5, 1.0, 'Count of Languages')]

# %% [markdown]
# I looked at the tweets for mentions of the final four countries by their specific names. The majority of the tweets mentioned France. There could be several reasons for this. On December 10 2022 there was a match between England and France played. France won that match. Many of the tweets that mentioned France also mentioned England. There were 71 tweets in the data set mentioning England. This would have been the most popular country in the data set by far which makes sense since most of the tweets were in the English language. Unforutantely they were eliminated and so any future marketing tie ins for the Fifa world cup have been eliminated and we need to focus on other opportunities.

# %%
country_bar()

# %% [markdown]
# Another attempt to identify the most popular Fifa world cup country was based on the location of the Twitter users account. Not all users tag with their geo location when creating a tweet so I felt the User Account location might be more reliable. Unfortunately Twitter users can list their location as being any where of their choosing. Many listed places such as Nottinham, England while others listed places as Earth, space, or Mars.  The majority had no location entered. This proved too unreliable for analysis.

# %%
location_list()
# Out:
# ['50.984736,-114.080062',
#  '',
#  '',
#  'mexico df',
#  'Hillingdon, London',
#  'Bangladesh',
#  '',
#  'Cornwall ',
#  'Auckland New Zealand ',
#  'Cornwall ',
#  '',
#  'Cornwall ',
#  '',
#  'England']

# %% [markdown]
# I had calculated the overall sentiment from the English tweets using the Vader sentiment analysis module. This merely look at the overall message and not necessarily if it was related to a particular team.  The majority of the tweets were positive. There were 398 positive tweets, 308 negative, and 177 neutral. When sampling the data many of the negative ones appearred to be related to the recent lose of England to France. Further gathering of tweets could provide a more accurate look at the true sentiment of Fifa World Cup fans.

# %%
sentiment_hist()
# Out:
# [Text(0.5, 1.0, 'English Language Tweet Sentiment to Fifa World Cup')]

# %% [markdown]
# To get a more accuracte portrayl of which countries, fans are most excited for in the final 4, I broke the tweets down based mentions of the final 4 countries.
#
# Most countries have positive sentiment to with France by far having the most positive sentiment. This could be due to the historic closesness between English and French speaking countries.

# %%
sentiment_grid()

# %% [markdown]
# ### Final Assessment
#
# The sample size set of 1000 tweets was too small and this would require resampling at various intervals in order to produce a more accurate picture of who fans are most excited for in the upcoming final four match. The sample collected had a heavy bias towards England. Since the time between games is a very short window, any changes to marketing promotional events would need to be made rapidly since there is a 4 day difference between rounds in the game. This would limit the time to resample Twitter and try to establish an unbiased look at the most popular teams since there will always be changing news, events, and sentiments towards teams, especially if they lose.
#
# When sampling at any given moment could collect a specific tirade of online hate/love towards a team, player, or scandal, but a large enough sample will compensate for this.  Sometimes there is no bad publicity, and just general engagement for a team whether good or bad can bring more viewers. Obviously this can be true to extent as long as their is no major public backlash event or campaign against a specific person, team, or sport. Examples would be the Subway tie ins with Jared Foggle. Another example is when in 2015 Fifa organization had a scandal where certain countries bought votes to host the world cup.
#
#
# Using Twitter will likely always produce a bias towards  specific language of tweets depending on the inputs chosen. Using @Fifa appears to have provided a mostly English lanaguage set of tweets. It then produced a bias towards England football team. To get an accurate picture, it will be necessary to gather tweets from several different words, at various times, using a larger sample size. This can produce an accurate picture for the marketing team, to select country focus on for promotional tie ins.
